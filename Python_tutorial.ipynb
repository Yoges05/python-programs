# %% [markdown]
# <a href="https://colab.research.google.com/github/Yoges05/python-programs/blob/main/Python_tutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
A = float(input("Enter the length:"))
B = float(input("Enter the width:"))
area = A*B
print("Area of the Rectangle:",area)
# Out:
# Enter the length:10
# Enter the width:05
# Area of the Rectangle: 50.0

# %%
A = float(input("Enter the side the Square:"))
area = A*A
print("Area of the square:",area)
# Out:
# Enter the side the Square:05
# Area of the square: 25.0

# %%
A = float(input("Enter the Breadth:"))
B = float(input("Enter the Height:"))
area = 0.5*A*B
print("Area of the Triangle:",area)
# Out:
# Enter the Breadth:05
# Enter the Height:10
# Area of the Triangle: 25.0

# %%
A = float(input("Enterb the radius:"))
area = 3.14*A*A
print("Area of the Circle:",area)
# Out:
# Enterb the radius:10
# Area of the Circle: 314.0
