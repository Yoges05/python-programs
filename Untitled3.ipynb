# %% [markdown]
# <a href="https://colab.research.google.com/github/Yoges05/python-programs/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("welcome")
# Out:
# welcome

# %%
A = input("Enter the word")
print("the given word is:",A)
# Out:
# Enter the worddhaam dhoom
# the given word is: dhaam dhoom
